# %%
import requests

# %%
pip install --upgrade 'library'
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already up-to-date: library in /storage/home/p/ppk5143/.local/lib/python3.8/site-packages (0.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
url = "https://services.cancerimagingarchive.net/nbia-api/services/v1/getContentsByName?name=nbia-33941643745631058"

r = requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
with open("/storage/home/ppk5143/DS440/project/volume/data/raw/data.zip", 'wb') as fd:
    for chunk in r.iter_content(chunk_size=128):
        fd.write(chunk)

# %%
pip install -U pydicom
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already up-to-date: pydicom in /storage/home/p/ppk5143/.local/lib/python3.8/site-packages (2.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import pydicom
filename = '/storage/home/ppk5143/DS440/project/volume/data/raw/00000001.dcm'
ds = pydicom.dcmread(filename)
plt.imshow(ds.pixel_array, cmap=plt.cm.bone)

# %%
# Data Load works just fine for the API.
